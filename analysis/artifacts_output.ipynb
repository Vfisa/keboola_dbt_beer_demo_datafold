# %%
import os
import json

# %%
## Setup
path = "data/artifacts/current/"
if not os.path.exists(path):os.makedirs(path)

# %%
run_results_raw = """
{
    "metadata": {
        "dbt_schema_version": "https://schemas.getdbt.com/dbt/run-results/v4.json",
        "dbt_version": "1.1.1",
        "generated_at": "2022-08-05T04:32:20.283580Z",
        "invocation_id": "3906facb-d5e6-49a5-9dac-958030d6fdd1",
        "env": {}
    },
    "results": [
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.800545Z",
                    "completed_at": "2022-08-05T04:32:19.804808Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.805205Z",
                    "completed_at": "2022-08-05T04:32:19.805233Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0055959224700927734,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.beers"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.806746Z",
                    "completed_at": "2022-08-05T04:32:19.810499Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.810800Z",
                    "completed_at": "2022-08-05T04:32:19.810807Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.004929065704345703,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.breweries"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.812159Z",
                    "completed_at": "2022-08-05T04:32:19.925789Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.926030Z",
                    "completed_at": "2022-08-05T04:32:19.926037Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.11467909812927246,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.orders"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.927014Z",
                    "completed_at": "2022-08-05T04:32:19.928244Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.928432Z",
                    "completed_at": "2022-08-05T04:32:19.928436Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0020110607147216797,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "seed.beer_analytics.seed_beers"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.929272Z",
                    "completed_at": "2022-08-05T04:32:19.930376Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.930558Z",
                    "completed_at": "2022-08-05T04:32:19.930562Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0018131732940673828,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "seed.beer_analytics.seed_breweries"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.931355Z",
                    "completed_at": "2022-08-05T04:32:19.940681Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.940896Z",
                    "completed_at": "2022-08-05T04:32:19.940901Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.010102987289428711,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.source_not_null_WORKSPACE_863912091_beers__brewery_id_.48bd3f3f34"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.941736Z",
                    "completed_at": "2022-08-05T04:32:19.944385Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.944584Z",
                    "completed_at": "2022-08-05T04:32:19.944589Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003367900848388672,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.source_not_null_WORKSPACE_863912091_beers__id_.5fa9d79542"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.945372Z",
                    "completed_at": "2022-08-05T04:32:19.948329Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.948533Z",
                    "completed_at": "2022-08-05T04:32:19.948538Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0036706924438476562,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.source_not_null_WORKSPACE_863912091_beers__name_.d658943614"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.949326Z",
                    "completed_at": "2022-08-05T04:32:19.954130Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:19.954335Z",
                    "completed_at": "2022-08-05T04:32:19.954340Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0055217742919921875,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.source_unique_WORKSPACE_863912091_beers__id_.c05632b229"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:19.955152Z",
                    "completed_at": "2022-08-05T04:32:20.231149Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.231393Z",
                    "completed_at": "2022-08-05T04:32:20.231400Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.2767932415008545,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.order_lines"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.232564Z",
                    "completed_at": "2022-08-05T04:32:20.234908Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.235120Z",
                    "completed_at": "2022-08-05T04:32:20.235125Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0031609535217285156,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.assert_ibu_0_100_range"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.235950Z",
                    "completed_at": "2022-08-05T04:32:20.238816Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.239012Z",
                    "completed_at": "2022-08-05T04:32:20.239017Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0035860538482666016,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.not_null_beers_beer_id.efaf5f5466"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.239810Z",
                    "completed_at": "2022-08-05T04:32:20.242374Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.242568Z",
                    "completed_at": "2022-08-05T04:32:20.242573Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003262042999267578,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.unique_beers_beer_id.594ed33081"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.243358Z",
                    "completed_at": "2022-08-05T04:32:20.245783Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.245980Z",
                    "completed_at": "2022-08-05T04:32:20.245984Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003131866455078125,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.beers_with_breweries"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.246873Z",
                    "completed_at": "2022-08-05T04:32:20.249960Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.250155Z",
                    "completed_at": "2022-08-05T04:32:20.250160Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003805875778198242,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.promo_deliveries"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.250954Z",
                    "completed_at": "2022-08-05T04:32:20.256221Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.256459Z",
                    "completed_at": "2022-08-05T04:32:20.256465Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.006042957305908203,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.relationships_order_lines_order_no__order_no__ref_orders_.35667b5672"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.257331Z",
                    "completed_at": "2022-08-05T04:32:20.259888Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.260084Z",
                    "completed_at": "2022-08-05T04:32:20.260089Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0032949447631835938,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.unique_order_lines_order_line.0b400fba5e"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.260869Z",
                    "completed_at": "2022-08-05T04:32:20.263684Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.263881Z",
                    "completed_at": "2022-08-05T04:32:20.263885Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003522157669067383,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "model.beer_analytics.sales"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.264748Z",
                    "completed_at": "2022-08-05T04:32:20.268155Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.268364Z",
                    "completed_at": "2022-08-05T04:32:20.268369Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.004145145416259766,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.not_null_beers_with_breweries_beer_id.06c4b94123"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.269174Z",
                    "completed_at": "2022-08-05T04:32:20.271876Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.272090Z",
                    "completed_at": "2022-08-05T04:32:20.272095Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003442049026489258,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.not_null_beers_with_breweries_brewery_id.1725a2e6dc"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.272902Z",
                    "completed_at": "2022-08-05T04:32:20.275395Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.275587Z",
                    "completed_at": "2022-08-05T04:32:20.275592Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003197908401489258,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.unique_beers_with_breweries_beer_id.aeaa7c6743"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.276385Z",
                    "completed_at": "2022-08-05T04:32:20.278880Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.279073Z",
                    "completed_at": "2022-08-05T04:32:20.279078Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.003201007843017578,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.not_null_sales_order_line.254f52e82a"
        },
        {
            "status": "success",
            "timing": [
                {
                    "name": "compile",
                    "started_at": "2022-08-05T04:32:20.279854Z",
                    "completed_at": "2022-08-05T04:32:20.282385Z"
                },
                {
                    "name": "execute",
                    "started_at": "2022-08-05T04:32:20.282576Z",
                    "completed_at": "2022-08-05T04:32:20.282581Z"
                }
            ],
            "thread_id": "Thread-1",
            "execution_time": 0.0032308101654052734,
            "adapter_response": {},
            "message": null,
            "failures": null,
            "unique_id": "test.beer_analytics.not_null_sales_order_no.2f24730369"
        }
    ],
    "elapsed_time": 1.502380132675171,
    "args": {
        "write_json": true,
        "use_colors": true,
        "printer_width": 80,
        "version_check": true,
        "partial_parse": true,
        "static_parser": true,
        "profiles_dir": "/Users/martin/.dbt",
        "send_anonymous_usage_stats": false,
        "event_buffer_size": 100000,
        "quiet": false,
        "no_print": false,
        "compile": true,
        "which": "generate",
        "rpc_method": "docs.generate",
        "indirect_selection": "eager"
    }
}
"""

# %%
run_results = json.loads(run_results_raw)
run_results
# Out:
# {'metadata': {'dbt_schema_version': 'https://schemas.getdbt.com/dbt/run-results/v4.json',
#   'dbt_version': '1.1.1',
#   'generated_at': '2022-08-05T04:32:20.283580Z',
#   'invocation_id': '3906facb-d5e6-49a5-9dac-958030d6fdd1',
#   'env': {}},
#  'results': [{'status': 'success',
#    'timing': [{'name': 'compile',
#      'started_at': '2022-08-05T04:32:19.800545Z',
#      'completed_at': '2022-08-05T04:32:19.804808Z'},
#     {'name': 'execute',
#      'started_at': '2022-08-05T04:32:19.805205Z',
#      'completed_at': '2022-08-05T04:32:19.805233Z'}],
#    'thread_id': 'Thread-1',
#    'execution_time': 0.0055959224700927734,
#    'adapter_response': {},
#    'message': None,
#    'failures': None,
#    'unique_id': 'model.beer_analytics.beers'},
#   {'status': 'success',
#    'timing': [{'name': 'compile',
#      'started_at': '2022-08-05T04:32:19.806746Z',
#      'completed_at': '2022-08-05T04:32:19.810499Z'},
#     {'name': 'execute',
# ...

# %%
## Create artifact
filename = "run_results.json"
with open(path+filename, "w") as file:
  #file.write("value1")
  json.dump(run_results, file)

# %%
def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

list_files("data/artifacts/")
# Out:
# /
#     currentrun_results.json
# current/
#     run_results.json

# %%
import os
import glob

# Download
print(glob.glob("/data/artifacts/runs/*/*"))

# Upload
path = "data/artifacts/current"
if not os.path.exists(path):os.makedirs(path)
with open("/data/artifacts/current/myartifact1", "w") as file:
    file.write("value1")
